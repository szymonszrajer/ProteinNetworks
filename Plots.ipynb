# %%
import matplotlib.pyplot as plt
paddings = ["post", "extreme", "mid"]
values_task1 = [66.5, 64.5, 70.3]
values_task2 = [67.4, 62.3, 80.2]
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
ax1.bar(paddings, values_task1, color = "black")
ax1.set_title("Task 1")
ax1.set_ylabel('Accuracy [%]')
for i, v in enumerate(values_task1):
    ax1.text(i - 0.1, v + 2, str(v), ha = "left")
ax2.bar(paddings, values_task2, color = "cyan")
ax2.set_title("Task 2")
ax2.set_ylabel('Accuracy [%]')
for i, v in enumerate(values_task2):
    ax2.text(i - 0.1, v + 2, str(v), ha = "left")
fig.suptitle("Best Padding Search")
ax1.set_ylim(50, 90)
ax2.set_ylim(50, 90)
plt.show()

# %%
task1_labels = ["no convolution", "1 convolution", "5 convolutions"]
values_task11 = [70.1, 69.5, 71.1]
values_task21 = [80.5, 78.9, 83.1]
values_task12 = [79.4, 78.8, 80.1]
values_task22 = [85.2, 85.9, 88.1]
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 10))
ax1.bar(task1_labels, values_task11, color ="#FFCC99")
ax1.set_title("Task 1 - sequence")
ax3.bar(task1_labels, values_task12, color ="#98FB98")
ax3.set_title("Task 1 - physico-chemical")
for i, v in enumerate(values_task11):
    ax1.text(i - 0.1, v + 1, str(v), va='bottom', ha='left')
for i, v in enumerate(values_task12):
    ax3.text(i - 0.1, v + 1, str(v), va='bottom', ha='left')
ax2.bar(task1_labels, values_task21, color = "#FFA07A")
ax2.set_title("Task 2 - sequence")
ax4.bar(task1_labels, values_task22, color = "#54FF9F")
ax4.set_title("Task 2 - physico-chemical")
for i, v in enumerate(values_task21):
    ax2.text(i - 0.1 , v + 1, str(v), va='bottom', ha='left')
for i, v in enumerate(values_task22):
    ax4.text(i - 0.1, v + 1, str(v), va='bottom', ha='left')
ax1.set_ylim(50, 105)
ax2.set_ylim(50, 105)
ax3.set_ylim(50, 105)
ax4.set_ylim(50, 105)
ax1.set_ylabel('Accuracy [%]')
ax2.set_ylabel('Accuracy [%]')
ax3.set_ylabel('Accuracy [%]')
ax4.set_ylabel('Accuracy [%]')
#fig.suptitle("Dataset 1")
plt.show()

# %%
task1_labels = ["no convolution", "1 convolution", "5 convolutions"]
values_task11 = [82.9, 86.5, 83.5]
values_task21 = [88.3, 97.5, 96.9]
values_task12 = [78.8, 82.0, 81.1]
values_task22 = [77.2, 90.3, 90.1]
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 10))
ax1.bar(task1_labels, values_task11, color ="#FFCC99")
ax1.set_title("Task 1 - sequence")
ax3.bar(task1_labels, values_task12, color ="#98FB98")
ax3.set_title("Task 1 - physico-chemical")
for i, v in enumerate(values_task11):
    ax1.text(i - 0.1, v + 1, str(v), va='bottom', ha='left')
for i, v in enumerate(values_task12):
    ax3.text(i - 0.1, v + 1, str(v), va='bottom', ha='left')
ax2.bar(task1_labels, values_task21, color = "#FFA07A")
ax2.set_title("Task 2 - sequence")
ax4.bar(task1_labels, values_task22, color = "#54FF9F")
ax4.set_title("Task 2 - physico-chemical")
for i, v in enumerate(values_task21):
    ax2.text(i - 0.1 , v + 1, str(v), va='bottom', ha='left')
for i, v in enumerate(values_task22):
    ax4.text(i - 0.1, v + 1, str(v), va='bottom', ha='left')
ax1.set_ylim(50, 105)
ax2.set_ylim(50, 105)
ax3.set_ylim(50, 105)
ax4.set_ylim(50, 105)
ax1.set_ylabel('Accuracy [%]')
ax2.set_ylabel('Accuracy [%]')
ax3.set_ylabel('Accuracy [%]')
ax4.set_ylabel('Accuracy [%]')
#fig.suptitle("Dataset 1")
plt.show()

# %%
task1_labels = ["no convolution", "1 convolution", "5 convolutions"]
values_task11 = [88.8, 87.8, 93.1]
values_task21 = [91.4, 92.4, 95.2]
values_task12 = [94.7, 95.2, 93.2]
values_task22 = [97.3, 97.8, 97.4]
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 10))
ax1.bar(task1_labels, values_task11, color ="#FA8072")
ax1.set_title("Task 1 - sequence")
ax3.bar(task1_labels, values_task12, color ="#87CEEB")
ax3.set_title("Task 1 - physico-chemical")
for i, v in enumerate(values_task11):
    ax1.text(i - 0.1, v + 1, str(v), va='bottom', ha='left')
for i, v in enumerate(values_task12):
    ax3.text(i - 0.1, v + 1, str(v), va='bottom', ha='left')
ax2.bar(task1_labels, values_task21, color = "#FF69B4")
ax2.set_title("Task 2 - sequence")
ax4.bar(task1_labels, values_task22, color = "#B0E0E6")
ax4.set_title("Task 2 - physico-chemical")
for i, v in enumerate(values_task21):
    ax2.text(i - 0.1 , v + 1, str(v), va='bottom', ha='left')
for i, v in enumerate(values_task22):
    ax4.text(i - 0.1, v + 1, str(v), va='bottom', ha='left')
ax1.set_ylim(50, 105)
ax2.set_ylim(50, 105)
ax3.set_ylim(50, 105)
ax4.set_ylim(50, 105)
ax1.set_ylabel('Accuracy [%]')
ax2.set_ylabel('Accuracy [%]')
ax3.set_ylabel('Accuracy [%]')
ax4.set_ylabel('Accuracy [%]')
#fig.suptitle("Dataset 2")
plt.show()

# %%
task1_labels = ["no convolution", "1 convolution", "5 convolutions"]
values_task11 = [97.8, 99.6, 99.0]
values_task21 = [98.0, 100.0, 99.8]
values_task12 = [95.0, 98.0, 97.2]
values_task22 = [95.7, 99.6, 98.2]
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 10))
ax1.bar(task1_labels, values_task11, color ="#FA8072")
ax1.set_title("Task 1 - sequence")
ax3.bar(task1_labels, values_task12, color ="#87CEEB")
ax3.set_title("Task 1 - physico-chemical")
for i, v in enumerate(values_task11):
    ax1.text(i - 0.1, v + 1, str(v), va='bottom', ha='left')
for i, v in enumerate(values_task12):
    ax3.text(i - 0.1, v + 1, str(v), va='bottom', ha='left')
ax2.bar(task1_labels, values_task21, color = "#FF69B4")
ax2.set_title("Task 2 - sequence")
ax4.bar(task1_labels, values_task22, color = "#B0E0E6")
ax4.set_title("Task 2 - physico-chemical")
for i, v in enumerate(values_task21):
    ax2.text(i - 0.1 , v + 1, str(v), va='bottom', ha='left')
for i, v in enumerate(values_task22):
    ax4.text(i - 0.1, v + 1, str(v), va='bottom', ha='left')
ax1.set_ylim(50, 105)
ax2.set_ylim(50, 105)
ax3.set_ylim(50, 105)
ax4.set_ylim(50, 105)
ax1.set_ylabel('Accuracy [%]')
ax2.set_ylabel('Accuracy [%]')
ax3.set_ylabel('Accuracy [%]')
ax4.set_ylabel('Accuracy [%]')
#fig.suptitle("Dataset 2")
plt.show()

# %%
task1_labels = ["no convolution", "1 convolution", "5 convolutions"]
values_task11 = [46, 53, 55]
values_task21 = [64, 62, 63]
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))
ax1.bar(task1_labels, values_task11, color ="#FA8072")
ax1.set_title("Task 2 - sequence")
ax2.bar(task1_labels, values_task21, color ="#87CEEB")
ax2.set_title("Task 2 - physico-chemical")
for i, v in enumerate(values_task11):
    ax1.text(i - 0.05, v + 1, str(v), va='bottom', ha='left')
for i, v in enumerate(values_task21):
    ax2.text(i - 0.05, v + 1, str(v), va='bottom', ha='left')
ax1.set_ylim(40, 80)
ax2.set_ylim(40, 80)
ax1.set_ylabel('Accuracy [%]')
ax2.set_ylabel('Accuracy [%]')
#fig.suptitle("Dataset 3")
plt.show()
